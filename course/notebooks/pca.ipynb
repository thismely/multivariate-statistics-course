# %% [markdown]
# # 主成分分析 PCA
#
# 本 Notebook 使用与 `course/code/pca.py` 相同的固定种子合成数据。先标准化，再用 PCA 提取两个正交方向；贡献率描述总方差的解释比例，不能作因果解释。

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
SEED = 6101  # fixed synthetic seed
rng = np.random.default_rng(SEED)
latent = rng.normal(size=(180, 2))
loading = np.array([[.88,.12],[.76,.22],[.18,.90],[-.18,.82],[.60,-.30]])
X = latent @ loading.T + rng.normal(scale=.20, size=(180, 5))
X = X * np.array([20, 10, 5, 2, 50]) + np.array([100, 40, 8, 2, 300])
Xz = StandardScaler().fit_transform(X)
pca = PCA(n_components=2).fit(Xz)
pca.explained_variance_ratio_

# %%
scores = pca.transform(Xz)
loadings = pca.components_.T * np.sqrt(pca.explained_variance_)
scores.shape, loadings.shape
